# %%
import os
import argparse
from solver import Solver
from data_loader import get_loader
from torch.backends import cudnn
import numpy as np
from datetime import datetime
import json

def str2bool(v):
    return v.lower() in ('true')

def main(config):
    # For fast training.
    cudnn.benchmark = True

    # Create directories if not exist.
    if not os.path.exists(config.log_dir):
        os.makedirs(config.log_dir)
    if not os.path.exists(config.model_save_dir):
        os.makedirs(config.model_save_dir)
    if not os.path.exists(config.sample_dir):
        os.makedirs(config.sample_dir)
    if not os.path.exists(config.result_dir):
        os.makedirs(config.result_dir)

    # Data loader.
    celeba_loader = None
    rafd_loader = None

    if config.dataset in ['CelebA', 'Both']:
        celeba_loader = get_loader(config.celeba_image_dir, config.attr_path, config.selected_attrs,
                                   config.celeba_crop_size, config.image_size, config.batch_size,
                                   'CelebA', config.mode, config.num_workers)
    if config.dataset in ['RaFD', 'Both']:
        rafd_loader = get_loader(config.rafd_image_dir, None, None,
                                 config.rafd_crop_size, config.image_size, config.batch_size,
                                 'RaFD', config.mode, config.num_workers)
    

    # Solver for training and testing StarGAN.
    solver = Solver(celeba_loader, rafd_loader, config)

    if config.mode == 'train':
        if config.dataset in ['CelebA', 'RaFD']:
            solver.train()
        elif config.dataset in ['Both']:
            solver.train_multi()
    elif config.mode == 'test':
        if config.dataset in ['CelebA', 'RaFD']:
            solver.test()
        elif config.dataset in ['Both']:
            solver.test_multi()

# %%
class Config():
    """Params"""
    def random_G_lr(self):
        return np.random.uniform(10**-3, 10**-5)

    def random_D_lr(self):
        return np.random.uniform(10**-3, 10**-5)

    def random_n_critic(self):
        return int(np.random.randint(1, 11, size=1)[0])
    
    def random_Adam_beta1(self):
        return np.random.uniform(0.5, 0.9)
    
    def dir_name(self):
        return 'stargan/' + datetime.now().strftime("%m%d-%H:%M:%S")
    
    def dump(self):
        if not os.path.exists(self.dir):
            os.makedirs(self.dir)
        with open(self.dir +'/config.json','w') as f:
            json.dump({'g_lr': self.g_lr, 'd_lr': self.d_lr, 'n_critic': self.n_critic, 'Adam_beta1': self.beta1, 'selected_attrs': self.selected_attrs}, fp=f, sort_keys=True, indent=4)
        print(json.dumps({'g_lr': self.g_lr, 'd_lr': self.d_lr, 'n_critic': self.n_critic, 'Adam_beta1': self.beta1, 'selected_attrs': self.selected_attrs}, sort_keys=True, indent=4))

    def __init__(self):
        # Model configuration.
        self.c_dim = 5 #adjust for selected attributes
        self.c2_dim = 8
        self.celeba_crop_size = 178
        self.rafd_crop_size=256
        self.image_size = 128
        self.g_conv_dim = 64
        self.d_conv_dim = 64
        self.g_repeat_num = 6
        self.d_repeat_num = 6
        self.lambda_cls = 1
        self.lambda_rec = 10
        self.lambda_gp = 10
        
        # Training configuration.
        self.dataset = 'CelebA'
        self.batch_size = 16
        self.num_iters = 20000
        self.num_iters_decay = 20000
        self.g_lr = self.random_G_lr()
        self.d_lr = self.random_D_lr()
        self.n_critic = self.random_n_critic()
        self.beta1 = self.random_Adam_beta1()
        self.beta2 = 0.999
        self.resume_iters = None
        self.selected_attrs = ['5_o_Clock_Shadow', 'Arched_Eyebrows', 'Attractive', 'Bags_Under_Eyes', 'Bald', 'Bangs', 'Big_Lips',
            'Big_Nose', 'Black_Hair', 'Blond_Hair', 'Blurry', 'Brown_Hair', 'Bushy_Eyebrows', 'Chubby',
            'Double_Chin', 'Eyeglasses', 'Goatee', 'Gray_Hair', 'Heavy_Makeup', 'High_Cheekbones', 'Male',
            'Mouth_Slightly_Open', 'Mustache', 'Narrow_Eyes', 'No_Beard', 'Oval_Face', 'Pale_Skin', 'Pointy_Nose',
            'Receding_Hairline', 'Rosy_Cheeks', 'Sideburns', 'Smiling', 'Straight_Hair', 'Wavy_Hair',
            'Wearing_Earrings', 'Wearing_Hat', 'Wearing_Lipstick', 'Wearing_Necklace', 'Wearing_Necktie', 'Young'
            ]
        self.c_dim = len(self.selected_attrs)
        
        # Test configuration.
        self.test_iters = 20000
        
        # Miscellaneous.
        self.num_workers = 1
        self.mode = 'train'
        self.use_tensorboard = True
        
        # Directories.
        self.celeba_image_dir = 'data/CelebA_nocrop/images'
        self.attr_path = 'data/list_attr_celeba.txt'
        self.rafd_image_dir = 'data/RaFD/train'
        self.dir = self.dir_name()
        self.log_dir = self.dir +'/logs'
        self.model_save_dir = self.dir + '/models'
        self.sample_dir = self.dir + '/samples'
        self.result_dir = self.dir + '/results'
        
        #Step size
        self.log_step = 10
        self.sample_step = 1000
        self.model_save_step = 10000
        self.lr_update_step = 1000
        
        self.dump()

# %%
config = Config()
# Out:
# {
#     "Adam_beta1": 0.8412060106311363,
#     "d_lr": 0.00039881362401106226,
#     "g_lr": 0.00017279763335057352,
#     "n_critic": 6,
#     "selected_attrs": [
#         "5_o_Clock_Shadow",
#         "Arched_Eyebrows",
#         "Attractive",
#         "Bags_Under_Eyes",
#         "Bald",
#         "Bangs",
#         "Big_Lips",
#         "Big_Nose",
#         "Black_Hair",
#         "Blond_Hair",
#         "Blurry",
#         "Brown_Hair",
#         "Bushy_Eyebrows",
#         "Chubby",
#         "Double_Chin",
#         "Eyeglasses",
#         "Goatee",
#         "Gray_Hair",
#         "Heavy_Makeup",
#         "High_Cheekbones",
#         "Male",
#         "Mouth_Slightly_Open",
#         "Mustache",
#         "Narrow_Eyes",
#         "No_Beard",
#         "Oval_Face",
#         "Pale_Skin",
#         "Pointy_Nose",
#         "Receding_Hairline",
#         "Rosy_Cheeks",
#         "Sideburns",
#         "Smiling",
#         "Straight_Hair",
#         "Wavy_Hair",
#         "Wearing_Earrings",
#         "Wearing_Hat",
#         "Wearing_Lipstick",
#         "Wearing_Necklace",
#         "Wearing_Necktie",
#         "Young"
#     ]
# }

# %%
main(config)
# Out:
# Finished preprocessing the CelebA dataset...
# Generator(
#   (main): Sequential(
#     (0): Conv2d(43, 64, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#     (1): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (4): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace)
#     (6): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (7): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU(inplace)
#     (9): ResidualBlock(
#       (main): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (10): ResidualBlock(
#       (main): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (11): ResidualBlock(
#       (main): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (12): ResidualBlock(
#       (main): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (13): ResidualBlock(
#       (main): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (14): ResidualBlock(
#       (main): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (15): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (16): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (17): ReLU(inplace)
#     (18): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (19): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (20): ReLU(inplace)
#     (21): Conv2d(64, 3, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#     (22): Tanh()
#   )
# )
# G
# The number of parameters: 8540288
# Discriminator(
#   (main): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (5): LeakyReLU(negative_slope=0.01)
#     (6): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (7): LeakyReLU(negative_slope=0.01)
#     (8): Conv2d(512, 1024, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (9): LeakyReLU(negative_slope=0.01)
#     (10): Conv2d(1024, 2048, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (11): LeakyReLU(negative_slope=0.01)
#   )
#   (conv1): Conv2d(2048, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (conv2): Conv2d(2048, 40, kernel_size=(2, 2), stride=(1, 1), bias=False)
# )
# D
# The number of parameters: 45048768
# Start training...
# /home/paperspace/.pyenv/versions/anaconda3-5.2.0/lib/python3.5/site-packages/torch/nn/functional.py:52: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Elapsed [0:00:03], Iteration [10/20000], D/loss_gp: 0.1742, D/loss_fake: 2.6247, D/loss_cls: 18.0657, D/loss_real: -5.2827
# Elapsed [0:00:06], Iteration [20/20000], D/loss_gp: 0.1148, D/loss_fake: -0.8097, D/loss_cls: 20.0472, D/loss_real: -15.2547
# Elapsed [0:00:09], Iteration [30/20000], D/loss_gp: 0.5548, D/loss_cls: 24.6008, G/loss_rec: 0.4473, D/loss_real: -36.6399, G/loss_cls: 31.6630, G/loss_fake: 7.1860, D/loss_fake: 3.1525
# Elapsed [0:00:11], Iteration [40/20000], D/loss_gp: 1.3533, D/loss_fake: 13.0501, D/loss_cls: 22.6091, D/loss_real: -56.2784
# Elapsed [0:00:14], Iteration [50/20000], D/loss_gp: 0.2143, D/loss_fake: 5.8615, D/loss_cls: 22.0538, D/loss_real: -31.5923
# Elapsed [0:00:17], Iteration [60/20000], D/loss_gp: 0.2950, D/loss_cls: 17.9168, G/loss_rec: 0.3887, D/loss_real: -31.3555, G/loss_cls: 22.4623, G/loss_fake: -12.4109, D/loss_fake: 8.2200
# Elapsed [0:00:20], Iteration [70/20000], D/loss_gp: 0.2878, D/loss_fake: 3.0479, D/loss_cls: 17.2136, D/loss_real: -30.1921
# Elapsed [0:00:22], Iteration [80/20000], D/loss_gp: 0.0664, D/loss_fake: 11.3066, D/loss_cls: 19.4460, D/loss_real: -23.7160
# Elapsed [0:00:25], Iteration [90/20000], D/loss_gp: 0.1501, D/loss_cls: 20.7015, G/loss_rec: 0.7465, D/loss_real: -29.3563, G/loss_cls: 23.4106, G/loss_fake: 0.6381, D/loss_fake: 10.9567
# Elapsed [0:00:28], Iteration [100/20000], D/loss_gp: 0.1688, D/loss_fake: 15.1804, D/loss_cls: 19.1951, D/loss_real: -25.1811
# Elapsed [0:00:30], Iteration [110/20000], D/loss_gp: 0.1326, D/loss_fake: 11.1478, D/loss_cls: 15.9910, D/loss_real: -21.7439
# Elapsed [0:00:33], Iteration [120/20000], D/loss_gp: 0.2767, D/loss_cls: 17.4194, G/loss_rec: 0.4710, D/loss_real: -30.9041, G/loss_cls: 17.8193, G/loss_fake: -12.0773, D/loss_fake: 13.5065
# Elapsed [0:00:36], Iteration [130/20000], D/loss_gp: 0.1816, D/loss_fake: 8.0327, D/loss_cls: 16.7827, D/loss_real: -18.2567
# Elapsed [0:00:39], Iteration [140/20000], D/loss_gp: 0.5750, D/loss_fake: 6.0946, D/loss_cls: 19.1918, D/loss_real: -18.9930
# Elapsed [0:00:41], Iteration [150/20000], D/loss_gp: 0.2464, D/loss_cls: 16.9937, G/loss_rec: 0.4248, D/loss_real: -18.3360, G/loss_cls: 18.5662, G/loss_fake: -1.9097, D/loss_fake: 4.9913
# Elapsed [0:00:44], Iteration [160/20000], D/loss_gp: 0.1435, D/loss_fake: 0.1744, D/loss_cls: 16.9945, D/loss_real: -14.1687
# Elapsed [0:00:47], Iteration [170/20000], D/loss_gp: 0.3394, D/loss_fake: -1.7169, D/loss_cls: 15.8962, D/loss_real: -13.5503
# Elapsed [0:00:49], Iteration [180/20000], D/loss_gp: 0.1142, D/loss_cls: 16.7788, G/loss_rec: 0.4474, D/loss_real: -12.5815, G/loss_cls: 19.3511, G/loss_fake: 2.5310, D/loss_fake: -2.0020
# Elapsed [0:00:52], Iteration [190/20000], D/loss_gp: 0.0928, D/loss_fake: 5.1650, D/loss_cls: 17.9744, D/loss_real: -19.5058
# Elapsed [0:00:55], Iteration [200/20000], D/loss_gp: 0.8451, D/loss_fake: 5.7387, D/loss_cls: 16.3146, D/loss_real: -23.7108
# Elapsed [0:00:58], Iteration [210/20000], D/loss_gp: 0.1815, D/loss_cls: 14.8462, G/loss_rec: 0.3997, D/loss_real: -10.9191, G/loss_cls: 19.5990, G/loss_fake: -1.3445, D/loss_fake: -2.9624
# Elapsed [0:01:00], Iteration [220/20000], D/loss_gp: 0.1223, D/loss_fake: 0.5588, D/loss_cls: 16.9688, D/loss_real: -13.9818
# Elapsed [0:01:03], Iteration [230/20000], D/loss_gp: 0.6466, D/loss_fake: -3.1101, D/loss_cls: 16.6411, D/loss_real: -14.5965
# Elapsed [0:01:06], Iteration [240/20000], D/loss_gp: 0.3377, D/loss_cls: 15.6716, G/loss_rec: 0.3863, D/loss_real: -23.1660, G/loss_cls: 18.5403, G/loss_fake: -1.4458, D/loss_fake: 0.0304
# Elapsed [0:01:08], Iteration [250/20000], D/loss_gp: 0.5728, D/loss_fake: 5.0939, D/loss_cls: 17.3411, D/loss_real: -27.3173
# Elapsed [0:01:11], Iteration [260/20000], D/loss_gp: 0.4922, D/loss_fake: 8.9563, D/loss_cls: 16.6584, D/loss_real: -35.2645
# Elapsed [0:01:14], Iteration [270/20000], D/loss_gp: 0.1329, D/loss_cls: 16.0555, G/loss_rec: 0.3813, D/loss_real: -15.3203, G/loss_cls: 19.3416, G/loss_fake: -1.7346, D/loss_fake: -1.2684
# Elapsed [0:01:16], Iteration [280/20000], D/loss_gp: 0.1349, D/loss_fake: 0.3973, D/loss_cls: 16.6816, D/loss_real: -14.3111
# Elapsed [0:01:19], Iteration [290/20000], D/loss_gp: 0.4462, D/loss_fake: 17.0180, D/loss_cls: 19.0705, D/loss_real: -37.0706
# Elapsed [0:01:22], Iteration [300/20000], D/loss_gp: 0.5145, D/loss_cls: 16.9156, G/loss_rec: 0.3569, D/loss_real: -30.2992, G/loss_cls: 19.4946, G/loss_fake: -11.5672, D/loss_fake: 7.5128
# Elapsed [0:01:25], Iteration [310/20000], D/loss_gp: 0.3062, D/loss_fake: 6.1746, D/loss_cls: 16.6867, D/loss_real: -26.3934
# Elapsed [0:01:27], Iteration [320/20000], D/loss_gp: 0.4732, D/loss_fake: 10.4455, D/loss_cls: 16.9518, D/loss_real: -27.7485
# Elapsed [0:01:30], Iteration [330/20000], D/loss_gp: 0.3426, D/loss_cls: 17.3733, G/loss_rec: 0.3349, D/loss_real: -26.5577, G/loss_cls: 18.8375, G/loss_fake: -6.1114, D/loss_fake: 9.5670
# Elapsed [0:01:33], Iteration [340/20000], D/loss_gp: 0.3995, D/loss_fake: 7.3457, D/loss_cls: 17.0067, D/loss_real: -25.5159
# Elapsed [0:01:35], Iteration [350/20000], D/loss_gp: 0.1882, D/loss_fake: 1.6553, D/loss_cls: 15.0701, D/loss_real: -14.7310
# Elapsed [0:01:38], Iteration [360/20000], D/loss_gp: 0.3832, D/loss_cls: 13.9204, G/loss_rec: 0.3452, D/loss_real: -31.4613, G/loss_cls: 20.4901, G/loss_fake: -3.7050, D/loss_fake: 10.4256
# Elapsed [0:01:41], Iteration [370/20000], D/loss_gp: 0.1721, D/loss_fake: 3.2422, D/loss_cls: 17.0774, D/loss_real: -15.0418
# Elapsed [0:01:44], Iteration [380/20000], D/loss_gp: 0.4300, D/loss_fake: 9.6422, D/loss_cls: 17.4966, D/loss_real: -28.6484
# Elapsed [0:01:46], Iteration [390/20000], D/loss_gp: 0.3159, D/loss_cls: 13.1451, G/loss_rec: 0.3339, D/loss_real: -14.7791, G/loss_cls: 21.5355, G/loss_fake: 0.6349, D/loss_fake: -0.7922
# Elapsed [0:01:49], Iteration [400/20000], D/loss_gp: 0.2594, D/loss_fake: -0.9571, D/loss_cls: 17.8946, D/loss_real: -13.1278
# Elapsed [0:01:52], Iteration [410/20000], D/loss_gp: 0.5727, D/loss_fake: 11.9449, D/loss_cls: 16.9883, D/loss_real: -28.8863
# Elapsed [0:01:55], Iteration [420/20000], D/loss_gp: 0.2785, D/loss_cls: 14.6326, G/loss_rec: 0.3530, D/loss_real: -21.9759, G/loss_cls: 22.7216, G/loss_fake: -7.7947, D/loss_fake: 5.3242
# Elapsed [0:01:57], Iteration [430/20000], D/loss_gp: 0.2064, D/loss_fake: 5.2104, D/loss_cls: 14.1719, D/loss_real: -22.6995
# Elapsed [0:02:00], Iteration [440/20000], D/loss_gp: 0.3412, D/loss_fake: 4.5458, D/loss_cls: 15.5768, D/loss_real: -24.4885
# Elapsed [0:02:03], Iteration [450/20000], D/loss_gp: 0.4246, D/loss_cls: 14.3612, G/loss_rec: 0.3068, D/loss_real: -23.4491, G/loss_cls: 25.7696, G/loss_fake: -7.8166, D/loss_fake: 5.3480
# Elapsed [0:02:05], Iteration [460/20000], D/loss_gp: 0.4529, D/loss_fake: 6.5442, D/loss_cls: 14.7515, D/loss_real: -27.7757
# Elapsed [0:02:08], Iteration [470/20000], D/loss_gp: 0.5978, D/loss_fake: 10.0654, D/loss_cls: 14.2436, D/loss_real: -29.0926
# Elapsed [0:02:11], Iteration [480/20000], D/loss_gp: 0.4027, D/loss_cls: 13.0440, G/loss_rec: 0.3843, D/loss_real: -26.7913, G/loss_cls: 16.8255, G/loss_fake: -13.9019, D/loss_fake: 3.8430
# Elapsed [0:02:13], Iteration [490/20000], D/loss_gp: 0.3049, D/loss_fake: 3.8985, D/loss_cls: 13.8329, D/loss_real: -27.9499
# Elapsed [0:02:16], Iteration [500/20000], D/loss_gp: 0.4390, D/loss_fake: 8.5846, D/loss_cls: 15.2354, D/loss_real: -34.3067
# Elapsed [0:02:19], Iteration [510/20000], D/loss_gp: 0.3099, D/loss_cls: 15.8596, G/loss_rec: 0.3146, D/loss_real: -23.6858, G/loss_cls: 25.5740, G/loss_fake: -6.3250, D/loss_fake: 6.8557
# Elapsed [0:02:22], Iteration [520/20000], D/loss_gp: 0.4315, D/loss_fake: 9.9187, D/loss_cls: 15.2610, D/loss_real: -26.9138
# Elapsed [0:02:24], Iteration [530/20000], D/loss_gp: 0.4966, D/loss_fake: 18.9910, D/loss_cls: 14.0209, D/loss_real: -33.5527
# Elapsed [0:02:27], Iteration [540/20000], D/loss_gp: 0.2597, D/loss_cls: 13.6362, G/loss_rec: 0.3406, D/loss_real: -26.4439, G/loss_cls: 17.7980, G/loss_fake: -10.8462, D/loss_fake: 8.6635
# Elapsed [0:02:30], Iteration [550/20000], D/loss_gp: 0.1169, D/loss_fake: 6.0044, D/loss_cls: 15.5533, D/loss_real: -17.3762
# Elapsed [0:02:33], Iteration [560/20000], D/loss_gp: 0.2388, D/loss_fake: 9.7053, D/loss_cls: 13.2310, D/loss_real: -27.5478
# Elapsed [0:02:35], Iteration [570/20000], D/loss_gp: 0.0583, D/loss_cls: 15.0112, G/loss_rec: 0.3181, D/loss_real: -18.4197, G/loss_cls: 20.3491, G/loss_fake: -6.6191, D/loss_fake: 6.6777
# Elapsed [0:02:38], Iteration [580/20000], D/loss_gp: 0.4290, D/loss_fake: 4.1384, D/loss_cls: 16.2807, D/loss_real: -24.1932
# Elapsed [0:02:41], Iteration [590/20000], D/loss_gp: 0.1738, D/loss_fake: 2.8293, D/loss_cls: 13.2790, D/loss_real: -14.7393
# Elapsed [0:02:44], Iteration [600/20000], D/loss_gp: 0.1945, D/loss_cls: 15.7303, G/loss_rec: 0.3345, D/loss_real: -19.7160, G/loss_cls: 19.1049, G/loss_fake: -9.0409, D/loss_fake: 4.8499
# Elapsed [0:02:46], Iteration [610/20000], D/loss_gp: 0.3209, D/loss_fake: 10.5158, D/loss_cls: 13.2752, D/loss_real: -26.4592
# Elapsed [0:02:49], Iteration [620/20000], D/loss_gp: 0.1888, D/loss_fake: 5.6109, D/loss_cls: 12.5408, D/loss_real: -19.0552
# Elapsed [0:02:52], Iteration [630/20000], D/loss_gp: 0.1777, D/loss_cls: 15.1608, G/loss_rec: 0.3830, D/loss_real: -16.7810, G/loss_cls: 22.3638, G/loss_fake: -0.9900, D/loss_fake: -0.2317
# Elapsed [0:02:54], Iteration [640/20000], D/loss_gp: 0.2245, D/loss_fake: -0.9360, D/loss_cls: 15.4434, D/loss_real: -13.8814
# Elapsed [0:02:57], Iteration [650/20000], D/loss_gp: 0.1155, D/loss_fake: 12.0958, D/loss_cls: 12.4168, D/loss_real: -25.5790
# Elapsed [0:03:00], Iteration [660/20000], D/loss_gp: 0.3037, D/loss_cls: 14.5470, G/loss_rec: 0.3864, D/loss_real: -23.5796, G/loss_cls: 17.7796, G/loss_fake: -5.1477, D/loss_fake: 5.3254
# Elapsed [0:03:02], Iteration [670/20000], D/loss_gp: 0.2259, D/loss_fake: 5.0994, D/loss_cls: 13.5062, D/loss_real: -21.9515
# Elapsed [0:03:05], Iteration [680/20000], D/loss_gp: 0.2629, D/loss_fake: 12.1242, D/loss_cls: 13.5214, D/loss_real: -28.0691
# Elapsed [0:03:08], Iteration [690/20000], D/loss_gp: 0.2696, D/loss_cls: 13.7666, G/loss_rec: 0.3303, D/loss_real: -24.0214, G/loss_cls: 20.5575, G/loss_fake: -11.1360, D/loss_fake: 13.0688
# Elapsed [0:03:11], Iteration [700/20000], D/loss_gp: 0.0895, D/loss_fake: 8.3514, D/loss_cls: 14.8779, D/loss_real: -20.8954
# Elapsed [0:03:13], Iteration [710/20000], D/loss_gp: 0.1622, D/loss_fake: 6.2837, D/loss_cls: 13.1989, D/loss_real: -18.4293
# Elapsed [0:03:16], Iteration [720/20000], D/loss_gp: 0.1588, D/loss_cls: 12.5082, G/loss_rec: 0.3346, D/loss_real: -23.6049, G/loss_cls: 17.4212, G/loss_fake: -8.3851, D/loss_fake: 8.5978
# Elapsed [0:03:19], Iteration [730/20000], D/loss_gp: 0.1708, D/loss_fake: 7.0146, D/loss_cls: 14.3736, D/loss_real: -17.6976
# Elapsed [0:03:22], Iteration [740/20000], D/loss_gp: 0.1605, D/loss_fake: 9.8416, D/loss_cls: 13.6590, D/loss_real: -20.5924
# Elapsed [0:03:24], Iteration [750/20000], D/loss_gp: 0.0945, D/loss_cls: 13.5705, G/loss_rec: 0.2658, D/loss_real: -14.0055, G/loss_cls: 20.0097, G/loss_fake: -5.8611, D/loss_fake: 5.4260
# Elapsed [0:03:27], Iteration [760/20000], D/loss_gp: 0.1478, D/loss_fake: 9.1803, D/loss_cls: 13.6689, D/loss_real: -21.1342
# Elapsed [0:03:30], Iteration [770/20000], D/loss_gp: 0.0831, D/loss_fake: 14.4733, D/loss_cls: 12.7085, D/loss_real: -23.1502
# Elapsed [0:03:33], Iteration [780/20000], D/loss_gp: 0.2157, D/loss_cls: 12.8894, G/loss_rec: 0.2956, D/loss_real: -23.7611, G/loss_cls: 17.5033, G/loss_fake: -15.9577, D/loss_fake: 14.1869
# Elapsed [0:03:35], Iteration [790/20000], D/loss_gp: 0.0933, D/loss_fake: 12.0963, D/loss_cls: 12.4019, D/loss_real: -23.0627
# Elapsed [0:03:38], Iteration [800/20000], D/loss_gp: 0.0859, D/loss_fake: 10.3569, D/loss_cls: 12.7949, D/loss_real: -17.7913
# Elapsed [0:03:41], Iteration [810/20000], D/loss_gp: 0.1564, D/loss_cls: 13.0794, G/loss_rec: 0.3287, D/loss_real: -16.6309, G/loss_cls: 17.9108, G/loss_fake: -5.9210, D/loss_fake: 5.3058
# Elapsed [0:03:43], Iteration [820/20000], D/loss_gp: 0.1621, D/loss_fake: 10.2843, D/loss_cls: 11.2647, D/loss_real: -23.4298
# Elapsed [0:03:46], Iteration [830/20000], D/loss_gp: 0.1176, D/loss_fake: 16.1493, D/loss_cls: 14.3026, D/loss_real: -24.7758
# Elapsed [0:03:49], Iteration [840/20000], D/loss_gp: 0.1549, D/loss_cls: 11.6521, G/loss_rec: 0.3479, D/loss_real: -13.9897, G/loss_cls: 15.5554, G/loss_fake: -4.8835, D/loss_fake: 5.5521
# Elapsed [0:03:51], Iteration [850/20000], D/loss_gp: 0.1854, D/loss_fake: 3.5534, D/loss_cls: 15.3034, D/loss_real: -15.7344
# Elapsed [0:03:54], Iteration [860/20000], D/loss_gp: 0.1238, D/loss_fake: 10.1618, D/loss_cls: 13.0541, D/loss_real: -18.2885
# Elapsed [0:03:57], Iteration [870/20000], D/loss_gp: 0.0663, D/loss_cls: 13.9917, G/loss_rec: 0.3079, D/loss_real: -21.1146, G/loss_cls: 18.1891, G/loss_fake: -18.1507, D/loss_fake: 14.7614
# Elapsed [0:04:00], Iteration [880/20000], D/loss_gp: 0.1531, D/loss_fake: 9.8933, D/loss_cls: 13.6811, D/loss_real: -19.9323
# Elapsed [0:04:02], Iteration [890/20000], D/loss_gp: 0.2277, D/loss_fake: 11.2939, D/loss_cls: 16.9030, D/loss_real: -21.1960
# Elapsed [0:04:05], Iteration [900/20000], D/loss_gp: 0.0729, D/loss_cls: 14.4581, G/loss_rec: 0.3195, D/loss_real: -17.1016, G/loss_cls: 16.6871, G/loss_fake: -8.3023, D/loss_fake: 11.3078
# Elapsed [0:04:08], Iteration [910/20000], D/loss_gp: 0.0996, D/loss_fake: 3.9982, D/loss_cls: 12.0360, D/loss_real: -11.5466
# Elapsed [0:04:11], Iteration [920/20000], D/loss_gp: 0.0702, D/loss_fake: 7.5690, D/loss_cls: 11.8368, D/loss_real: -16.9164
# Elapsed [0:04:13], Iteration [930/20000], D/loss_gp: 0.1302, D/loss_cls: 12.8925, G/loss_rec: 0.3769, D/loss_real: -19.0849, G/loss_cls: 17.2659, G/loss_fake: -11.0235, D/loss_fake: 8.0099
# Elapsed [0:04:16], Iteration [940/20000], D/loss_gp: 0.1285, D/loss_fake: 9.7281, D/loss_cls: 11.7377, D/loss_real: -19.2330
# Elapsed [0:04:19], Iteration [950/20000], D/loss_gp: 0.1832, D/loss_fake: 10.8276, D/loss_cls: 13.9428, D/loss_real: -17.2908
# Elapsed [0:04:22], Iteration [960/20000], D/loss_gp: 0.0826, D/loss_cls: 13.8619, G/loss_rec: 0.3168, D/loss_real: -17.4987, G/loss_cls: 15.8526, G/loss_fake: -4.8239, D/loss_fake: 10.0541
# Elapsed [0:04:24], Iteration [970/20000], D/loss_gp: 0.1737, D/loss_fake: 9.3526, D/loss_cls: 11.6941, D/loss_real: -19.9449
# Elapsed [0:04:27], Iteration [980/20000], D/loss_gp: 0.1181, D/loss_fake: 9.3025, D/loss_cls: 12.0515, D/loss_real: -18.7226
# Elapsed [0:04:30], Iteration [990/20000], D/loss_gp: 0.1179, D/loss_cls: 12.5018, G/loss_rec: 0.3419, D/loss_real: -16.6917, G/loss_cls: 16.5137, G/loss_fake: -6.9627, D/loss_fake: 8.6562
# Elapsed [0:04:32], Iteration [1000/20000], D/loss_gp: 0.0440, D/loss_fake: 7.0964, D/loss_cls: 14.1645, D/loss_real: -13.7917
# Saved real and fake images into stargan/0926-03:27:04/samples/1000-images.jpg...
# Decayed learning rates, g_lr: 0.000172788993468906, d_lr: 0.0003987936833298617.
# Elapsed [0:04:38], Iteration [1010/20000], D/loss_gp: 0.1445, D/loss_fake: 11.9027, D/loss_cls: 11.6460, D/loss_real: -20.4403
# Elapsed [0:04:41], Iteration [1020/20000], D/loss_gp: 0.0417, D/loss_cls: 12.5535, G/loss_rec: 0.3073, D/loss_real: -13.4134, G/loss_cls: 16.6546, G/loss_fake: -7.4576, D/loss_fake: 7.0655
# Elapsed [0:04:44], Iteration [1030/20000], D/loss_gp: 0.0674, D/loss_fake: 7.8912, D/loss_cls: 12.3778, D/loss_real: -15.3036
# Elapsed [0:04:46], Iteration [1040/20000], D/loss_gp: 0.0656, D/loss_fake: 6.2352, D/loss_cls: 12.0294, D/loss_real: -13.4716
# Elapsed [0:04:49], Iteration [1050/20000], D/loss_gp: 0.0826, D/loss_cls: 13.8748, G/loss_rec: 0.3120, D/loss_real: -17.1109, G/loss_cls: 17.1323, G/loss_fake: -8.9207, D/loss_fake: 9.6532
# Elapsed [0:04:52], Iteration [1060/20000], D/loss_gp: 0.1047, D/loss_fake: 4.9440, D/loss_cls: 12.7175, D/loss_real: -13.0034
# Elapsed [0:04:55], Iteration [1070/20000], D/loss_gp: 0.0932, D/loss_fake: 8.0891, D/loss_cls: 12.6616, D/loss_real: -16.8751
# Elapsed [0:04:57], Iteration [1080/20000], D/loss_gp: 0.0762, D/loss_cls: 13.1521, G/loss_rec: 0.2734, D/loss_real: -16.7602, G/loss_cls: 18.5947, G/loss_fake: -8.2323, D/loss_fake: 7.8121
# Elapsed [0:05:00], Iteration [1090/20000], D/loss_gp: 0.0770, D/loss_fake: 6.8271, D/loss_cls: 13.3907, D/loss_real: -14.4313
# Elapsed [0:05:03], Iteration [1100/20000], D/loss_gp: 0.0907, D/loss_fake: 9.5144, D/loss_cls: 13.3542, D/loss_real: -17.3458
# Elapsed [0:05:06], Iteration [1110/20000], D/loss_gp: 0.0612, D/loss_cls: 12.4962, G/loss_rec: 0.3290, D/loss_real: -15.4853, G/loss_cls: 18.6163, G/loss_fake: -7.8853, D/loss_fake: 7.8746
# Elapsed [0:05:11], Iteration [1120/20000], D/loss_gp: 0.0915, D/loss_fake: 6.0699, D/loss_cls: 12.6935, D/loss_real: -13.9635
# Elapsed [0:05:19], Iteration [1130/20000], D/loss_gp: 0.0827, D/loss_fake: 24.0973, D/loss_cls: 12.3831, D/loss_real: -30.7831
# Elapsed [0:05:28], Iteration [1140/20000], D/loss_gp: 0.1374, D/loss_cls: 11.4977, G/loss_rec: 0.3305, D/loss_real: -18.1509, G/loss_cls: 14.2338, G/loss_fake: -10.4353, D/loss_fake: 10.3966
# Elapsed [0:05:37], Iteration [1150/20000], D/loss_gp: 0.1362, D/loss_fake: 6.4533, D/loss_cls: 13.1382, D/loss_real: -14.6808
# Elapsed [0:05:46], Iteration [1160/20000], D/loss_gp: 0.0903, D/loss_fake: 5.7752, D/loss_cls: 11.1435, D/loss_real: -13.6951
# Elapsed [0:05:55], Iteration [1170/20000], D/loss_gp: 0.0237, D/loss_cls: 13.8963, G/loss_rec: 0.2961, D/loss_real: -14.2838, G/loss_cls: 20.0778, G/loss_fake: -7.5734, D/loss_fake: 6.5294
# Elapsed [0:06:04], Iteration [1180/20000], D/loss_gp: 0.0972, D/loss_fake: 9.5893, D/loss_cls: 12.2087, D/loss_real: -16.5612
# Elapsed [0:06:13], Iteration [1190/20000], D/loss_gp: 0.0709, D/loss_fake: 7.6142, D/loss_cls: 12.2367, D/loss_real: -17.2281
# Elapsed [0:06:22], Iteration [1200/20000], D/loss_gp: 0.0441, D/loss_cls: 12.4770, G/loss_rec: 0.2747, D/loss_real: -14.1892, G/loss_cls: 16.4424, G/loss_fake: -6.5679, D/loss_fake: 7.8238
# Elapsed [0:06:30], Iteration [1210/20000], D/loss_gp: 0.1322, D/loss_fake: 18.7560, D/loss_cls: 13.6417, D/loss_real: -27.3224
# Elapsed [0:06:40], Iteration [1220/20000], D/loss_gp: 0.1753, D/loss_fake: 5.6589, D/loss_cls: 13.6377, D/loss_real: -12.4675
# Elapsed [0:06:49], Iteration [1230/20000], D/loss_gp: 0.1011, D/loss_cls: 14.0732, G/loss_rec: 0.3459, D/loss_real: -18.3405, G/loss_cls: 18.6107, G/loss_fake: -8.6286, D/loss_fake: 8.9462
# Elapsed [0:06:57], Iteration [1240/20000], D/loss_gp: 0.0901, D/loss_fake: 7.7845, D/loss_cls: 12.5015, D/loss_real: -18.2553
# Elapsed [0:07:06], Iteration [1250/20000], D/loss_gp: 0.0288, D/loss_fake: 6.7164, D/loss_cls: 11.7482, D/loss_real: -13.1259
# Elapsed [0:07:16], Iteration [1260/20000], D/loss_gp: 0.0836, D/loss_cls: 13.3635, G/loss_rec: 0.3150, D/loss_real: -11.2834, G/loss_cls: 19.0906, G/loss_fake: -6.3310, D/loss_fake: 4.7170
# Elapsed [0:07:24], Iteration [1270/20000], D/loss_gp: 0.0759, D/loss_fake: 7.4769, D/loss_cls: 12.5015, D/loss_real: -14.3946
